# %%
from PIL import Image
import imageio.v3 as iio
import os

def convert_heic_to_jpg(heic_path, jpg_path=None):
    """
    Convert a HEIC image to JPG using imageio and Pillow.

    Parameters:
    - heic_path (str): Input HEIC file path.
    - jpg_path (str, optional): Output JPG file path.

    Returns:
    - str: Path to the saved JPG image.
    """
    img = iio.imread(heic_path)  # imageio uses libheif backend
    image = Image.fromarray(img)

    if jpg_path is None:
        jpg_path = os.path.splitext(heic_path)[0] + '.jpg'

    image.save(jpg_path, 'JPEG')
    return jpg_path

# %%
import os
from PIL import Image
import pillow_heif

# Register HEIF opener for Pillow
pillow_heif.register_heif_opener()

def convert_and_delete_heic_recursive(root_folder):
    count = 0
    deleted = 0

    for dirpath, _, filenames in os.walk(root_folder):
        for filename in filenames:
            if filename.lower().endswith('.heic'):
                heic_path = os.path.join(dirpath, filename)
                jpg_filename = os.path.splitext(filename)[0] + '.jpg'
                jpg_path = os.path.join(dirpath, jpg_filename)

                try:
                    image = Image.open(heic_path)
                    image.save(jpg_path, 'JPEG')
                    os.remove(heic_path)
                    count += 1
                    deleted += 1
                    print(f"✅ Converted and deleted: {filename}")
                except Exception as e:
                    print(f"❌ Failed: {heic_path} | Error: {e}")

    print(f"\n🎉 Done! {count} converted, {deleted} deleted.")

# Run the script
# convert_and_delete_heic_recursive(r"C:\Users\yxia\Downloads")
# Out:
# ✅ Converted and deleted: IMG_0323.HEIC
# ✅ Converted and deleted: IMG_0324.HEIC
# ✅ Converted and deleted: IMG_0325.HEIC
# ✅ Converted and deleted: IMG_0326.HEIC
# ✅ Converted and deleted: IMG_0327.HEIC
# ✅ Converted and deleted: IMG_0328.HEIC
# ✅ Converted and deleted: IMG_0329.HEIC
# ✅ Converted and deleted: IMG_0330.HEIC
# ✅ Converted and deleted: IMG_0331.HEIC
# ✅ Converted and deleted: IMG_0332.HEIC
# ✅ Converted and deleted: IMG_0333.HEIC
# ✅ Converted and deleted: IMG_0334.HEIC
# ✅ Converted and deleted: IMG_0335.HEIC
# ✅ Converted and deleted: IMG_0336.HEIC
# ✅ Converted and deleted: IMG_0337.HEIC
# ✅ Converted and deleted: IMG_0338.HEIC
# ✅ Converted and deleted: IMG_0339.HEIC
# ✅ Converted and deleted: IMG_0340.HEIC
# ✅ Converted and deleted: IMG_0341.HEIC
# ✅ Converted and deleted: IMG_0342.HEIC
# ✅ Converted and deleted: IMG_0343.HEIC
# ✅ Converted and deleted: IMG_0344.HEIC
# ✅ Converted and deleted: IMG_0345.HEIC
# ✅ Converted and deleted: IMG_0346.HEIC
# ✅ Converted and deleted: IMG_0347.HEIC
# ✅ Converted and deleted: IMG_0348.HEIC
# ✅ Converted and deleted: IMG_0349.HEIC
# ✅ Converted and deleted: IMG_0350.HEIC
# ✅ Converted and deleted: IMG_0351.HEIC
# ✅ Converted and deleted: IMG_0352.HEIC
# ✅ Converted and deleted: IMG_0353.HEIC
# ✅ Converted and deleted: IMG_0354.HEIC
# ✅ Converted and deleted: IMG_0355.HEIC
# ✅ Converted and deleted: IMG_0356.HEIC
# ✅ Converted and deleted: IMG_0357.HEIC
# ✅ Converted and deleted: IMG_0358.HEIC
# ✅ Converted and deleted: IMG_0359.HEIC
# ✅ Converted and deleted: IMG_0360.HEIC
# ✅ Converted and deleted: IMG_0361.HEIC
# ✅ Converted and deleted: IMG_0362.HEIC
# ✅ Converted and deleted: IMG_0363.HEIC
# ✅ Converted and deleted: IMG_0364.HEIC
# ✅ Converted and deleted: IMG_0365.HEIC
# ✅ Converted and deleted: IMG_0366.HEIC
# ✅ Converted and deleted: IMG_0367.HEIC
# ✅ Converted and deleted: IMG_0368.HEIC
# ✅ Converted and deleted: IMG_0369.HEIC
# ✅ Converted and deleted: IMG_0370.HEIC
# ✅ Converted and deleted: IMG_0371.HEIC
# ✅ Converted and deleted: IMG_0372.HEIC
# ✅ Converted and deleted: IMG_0373.HEIC
# ✅ Converted and deleted: IMG_0374.HEIC
# ✅ Converted and deleted: IMG_0375.HEIC
# ✅ Converted and deleted: IMG_0376.HEIC
# ✅ Converted and deleted: IMG_0377.HEIC
# ✅ Converted and deleted: IMG_0383.HEIC
#
# 🎉 Done! 56 converted, 56 deleted.
